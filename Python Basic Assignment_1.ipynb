# %%
"""
1. In the below elements which of them are values or an expression? eg:- values can be integer 
or string and expressions will be mathematical operators. 
*
hello
-87.8 
- 
/ 
+ 
6

Ans: 
* expression
hello values
-87.8 values
- expression
/ expression
+ expression
6 values

2. What is the difference between string and variable?
Ans:Variable are used to store data in form of integar,string and more data type. However 
    string is a form of data type which denotes within single or double quotation and are 
    immutable for ex a = "ram" here a is variable and "ram" is string data type.

3. Describe three different data types.
Ans.There different data types :
   1. Numeric data type. These data types has numeric value like integar, floating number or 
   complex number.
   
   2.String. String is a form of data type which denotes within single or double quotation and 
   are immutable for example a = "ram" here "ram" is string data type.
   
   3.Dictionary. Dictionary is an unordered collection of key-value pairs.Dictionaries are 
   defined within braces{} in form of key:value pair. Key and value can be of any type.
   
4. What is an expression made up of? What do all expressions do?
Ans.Expression is a combination of values and functions. Values and functions are combined and 
    interpreted by the compiler to create a new value.

5. This assignment statements, like spam = 10. What is the difference between an
   expression and a statement?
Ans.Statement cannot be reduced to any value like spam = 10. However expression can produce some 
   value and it is a combination of variable and operations with value that results in any value. 
   for example 10 + 3

6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
Ans. 22

7. What should the values of the following two terms be?
 'spam'+ 'spamspam'
 'spam' * 3 
Ans. For both two terms it will be same output that is 'spamspamspam' 

8. Why is eggs a valid variable name while 100 is invalid?
Ans. It is a rule of paython that variable cannot start with the number and can only contain alpha 
     numeric characters and underscores.
     
9. What three functions can be used to get the integer, floating-point number, or string
version of a value?
Ans. We can use following functions:
    1. integer = int()
    2. floating-point number = float()
    3. string = str()
      
10. Why does this expression cause an error? How can you fix it?
    'I have eaten' + 99 + 'burritos.'
Ans.This expression cause an error because as per rule we can only concatenate string with string 
    only not integer. If we change 99 to string by putting it in '99' single or double quotation.
    'I have eaten' +' 99 ' + 'burritos.'

"""
