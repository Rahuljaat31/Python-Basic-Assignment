# %% [markdown]
# Ques.1 Add the current date to the text file today.txt as a string.

# %%
#Ans.1
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 03-09-2022

# %% [markdown]
# Ques.2 Read the text file today.txt into the string today_string

# %%
#Ans.2
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 03-09-2022

# %% [markdown]
# Ques.3 Parse the date from today_string.

# %%
#Ans.3
from datetime import datetime
parse = datetime.strptime(today_string, '%d-%m-%Y')
print(parse)
# Out:
# 2022-09-03 00:00:00

# %% [markdown]
# Ques.4 List the files in your current directory

# %%
#Ans.4
import os
os.listdir('.')
# Out:
# ['.astropy',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.ipynb',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.python_history',
#  '3D Objects',
#  'abc.docx',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'books.csv',
#  'books.db',
#  'classcar.ipynb',
#  'Contacts',
#  'Controlflow.ipynb',
#  'Cookies',
#  'deffunc.ipynb',
#  'Desktop',
#  'document.docx',
#  'Documents',
#  'Downloads',
#  'Exceptionhandling.ipynb',
#  'Favorites',
#  'fbtracker.csv',
#  'forifloop.ipynb',
#  'FullStackDataScience.pdf',
#  'IF else for forelse while.ipynb',
#  'Ifelifelse.ipynb',
#  'IntelGraphicsProfiles',
#  'IteratoriterableGeneratorfileop.ipynb',
#  'Links',
#  'Local Settings',
#  'logging.ipynb',
#  'modularCoding.ipynb',
#  'Music',
#  'My Documents',
#  'MYCODE.ipynb',
#  'myownproject',
#  'my_module.py',
#  'my_module.py.bak',
#  'NetHood',
#  'newp.jpg',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{37ac8ffa-468c-11ec-8392-d093ad310739}.TM.blf',
#  'NTUSER.DAT{37ac8ffa-468c-11ec-8392-d093ad310739}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{37ac8ffa-468c-11ec-8392-d093ad310739}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'OOPS29jan.ipynb',
#  'Pictures',
#  'polymorphism.ipynb',
#  'PrintHood',
#  'PycharmProjects',
#  'Python Basic Assignment_1.ipynb',
#  'Python Basic Assignment_10.ipynb',
#  'Python Basic Assignment_11.ipynb',
#  'Python Basic Assignment_12.ipynb',
#  'Python Basic Assignment_13.ipynb',
#  'Python Basic Assignment_14.ipynb',
#  'Python Basic Assignment_15.ipynb',
#  'Python Basic Assignment_16.ipynb',
#  'Python Basic Assignment_17.ipynb',
#  'Python Basic Assignment_18.ipynb',
#  'Python Basic Assignment_19.ipynb',
#  'Python Basic Assignment_2.ipynb',
#  'Python Basic Assignment_20.ipynb',
#  'Python Basic Assignment_21.ipynb',
#  'Python Basic Assignment_22.ipynb',
#  'Python Basic Assignment_23.ipynb',
#  'Python Basic Assignment_24.ipynb',
#  'Python Basic Assignment_25.ipynb',
#  'Python Basic Assignment_3.ipynb',
#  'Python Basic Assignment_4.ipynb',
#  'Python Basic Assignment_5.ipynb',
#  'Python Basic Assignment_6.ipynb',
#  'Python Basic Assignment_8.ipynb',
#  'Python Basic Assignment_9.ipynb',
#  'pythonProject',
#  'rahulpic.jpg',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'sqlconnect.ipynb',
#  'Start Menu',
#  'Templates',
#  'test.txt',
#  'today.txt',
#  'TRYEXCEPTIONELSEFINALLY.ipynb',
#  'Tuples.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Videos',
#  'zoo.py',
#  '__pycache__']

# %% [markdown]
# Ques.5 Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
#Ans.5
list_files = os.listdir('..')
print(list_files)
# Out:
# ['All Users', 'Default', 'Default User', 'defaultuser100000', 'desktop.ini', 'Public', 'rahul']

# %% [markdown]
# Ques.6 Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
#Ans.6 The below code did not run in Jupyter notebook however it worked in online compiler for Python

from multiprocessing import Process
import datetime as dt
import time
import random

def print_dt(sec):
   
    time.sleep(sec)
    print (f'Current time is = {dt.datetime.now().time()} \nProcess took {sec} second(s)')
    
for i in range(3):
    wait = random.uniform(1,5)
    res = Process(target = print_dt, args = (wait,))
    res.start()

# %%
#Output per online compiler
from IPython.display import Image
Image(filename='multiproc.jpg')#adding screenshot for reference

# %% [markdown]
# Ques.7 Create a date object of your day of birth.

# %%
#Ans.7
import datetime as dt

dob = dt.datetime(1986, 12, 31)

print(dob)
# Out:
# 1986-12-31 00:00:00

# %% [markdown]
# Ques.8 What day of the week was your day of birth?

# %%
#Ans.8
dob.weekday() # Here Monday is 0 so it was Wednesday.
# Out:
# 2

# %% [markdown]
# Ques.9 When will you be (or when were you) 10,000 days old?

# %%
#Ans.9
from datetime import timedelta

delta = timedelta(days=10000)

future_date = dob + delta

print (f'I was 10000 days old on {future_date}')
# Out:
# I was 10000 days old on 2014-05-18 00:00:00
